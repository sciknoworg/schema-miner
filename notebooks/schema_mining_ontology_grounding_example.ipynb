# %% [markdown]
# ## 🌐 Ontology Grounding with QUDT

# %% [markdown]
# Once a process schema is extracted, it can be semantically grounded using the [QUDT Ontologies](https://www.qudt.org/pages/HomePage.html) (Quantities, Units, Dimensions, and Data Types). This step ensures that schema attributes are linked to standardized scientific units and quantities, enabling interoperability and machine reasoning.

# %% [markdown]
# **Overview**
# 1. [Intalling Schema_miner](#installing-schema_miner)
# 2. [Configuration](#configuration)
# 3. [Ontology Grounding with QUDT Using LLM Prompting](#ontology-grounding-with-qudt-using-llm-prompting)
# 4. [Ontology Grounding with QUDT Using Agentic Workflow](#ontology-grounding-with-qudt-using-agentic-workflow)

# %% [markdown]
# ### 🗂️ Installing Schema_miner <a id='installing-schema-miner'></a>
#
# You can install schema-miner via **pip**:
#
# ```bash
# pip install -i https://test.pypi.org/simple/ schema-miner
# ```
#
# Or directly from GitHub (latest development version):
#
# ```bash
# pip install git+https://github.com/sciknoworg/schema-miner.git
# ```

# %% [markdown]
# ### 🛠️ Configuration <a id='configuration'></a>
#
# Before running schema-miner, configure your environment.

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Configure logging
import logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s"
)

# %%
from schema_miner.config.envConfig import EnvConfig
EnvConfig.OPENAI_api_key = '<insert-your-openai-key>'
EnvConfig.OPENAI_organization_id = '<insert-your-openi-organization-id>'

# %% [markdown]
# ### 🧪 Process Setup
#
# In this notebook, we demonstrate schema grounding on the domain of **Atomic Layer Deposition (ALD)**.
# This process involves alternating exposures of a substrate to chemical precursors, enabling precise thin-film growth at the atomic scale.
#
# > 💡 To adapt this notebook to a new domain, replace the domain name/description here and update the input literature paths in the Data Setup section.

# %%
# Add process name and process description whose schema have to be extracted
from schema_miner.config.processConfig import ProcessConfig
ProcessConfig.Process_name = "Atomic Layer Deposition"
ProcessConfig.Process_description = "An ALD process involves a series of controlled chemical reactions used to deposit thin films on a surface at an atomic level"

# %% [markdown]
# ### 🌐 Ontology Grounding with QUDT Using LLM Prompting <a id='prompt-grounding'></a>
#
# In this approach, we ask the LLM directly to suggest ontology matches for schema properties from its prior knowledge.

# %%
import json
from pathlib import Path
from schema_miner.ontology_grounding.prompt_qudt_grounding import prompt_based_qudt_grounding

# %%
# Large Language Model (LLM) to be used for Schema Extraction
llm_model_name = 'gpt-4o'

# Ground the schema with QUDT Ontology
process_schema = Path('../results1/Ideal Schema/Atomic-Layer-Deposition/experimental-ideal-schema.json')
results_file_path = Path("../results/qudt-grounded/Atomic-Layer-Deposition/experimental-schema")
schema = prompt_based_qudt_grounding(llm_model_name, process_schema, results_file_path, save_schema = True)

# %%
# Display the final Process Schema
logging.info(f'{ProcessConfig.Process_name} Schema:\n{json.dumps(schema, indent = 2)}')
# Out:
# 2025-09-11 17:06:27,377 - root - INFO - Atomic Layer Deposition Schema:
# {
#   "$schema": "http://json-schema.org/draft-07/schema#",
#   "title": "Atomic Layer Deposition (ALD) Process",
#   "description": "A schema representing the steps and parameters involved in setting up and characterizing an Atomic Layer Deposition process and the deposited film.",
#   "type": "object",
#   "properties": {
#     "ALDSystem": {
#       "type": "object",
#       "description": "Details about the ALD system used.",
#       "properties": {
#         "ALDMethod": {
#           "type": "string",
#           "description": "The specific ALD technique used, e.g., thermal ALD, plasma-enhanced ALD."
#         },
#         "MaterialDeposited": {
#           "type": "string",
#           "description": "The material being deposited, e.g., TiO2, Copper."
#         }
#       }
#     },
#     "ReactantSelection": {
#       "type": "object",
#       "description": "Selection of precursor and co-reactant based on their reactivity, volatility, and safety.",
#       "properties": {
#         "Precursor": {
#           "type": "string",
#           "description": "Chemical used as a precursor in the ALD process, e.g., tris(diethylamino)aluminum."
#         },
#         "CoReactant": {
#           "type": "string",
#           "description": "Chemical used as a co-reactant in the ALD process, e.g., water, hydrogen plasma."
#         },
#         "CarrierGas": {
#           "type": "string",
#           "description": "Type of carrier gas used in the delivery of reactants."
#         }
#       }
#     },
#     "ProcessParameters": {
#       "type": "object",
#       "description": "Specific parameters under which the ALD process is carried out.",
#       "properties": {
#         "Reactor": {
#           "type": "object",
#           "description": "Type and details of the reactor used for the ALD process.",
#           "properties": {
#             "Name": {
#               "type": "string",
#               "description": "Name of the reactor."
#             },
#             "Manufacturer": {
#               "type": "string",
#               "description": "Manufacturer of the reactor."
#             }
#           }
#         },
#         "DeliveryMethod": {
#           "type": "string",
#           "description": "Method of delivering the precursor and co-reactant to the reaction chamber."
#         },
#         "Temperature": {
#           "type": "object",
#           "description": "The temperature at which deposition occurs, typically in \u00b0C.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "properties": {
#                 "numericValue": {
#                   "type": "number"
#                 },
#                 "unit": {
#                   "type": "object",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Temperature"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "enum": [
#                         "https://qudt.org/vocab/unit/DEG_C"
#                       ]
#                     }
#                   }
#                 }
#               }
#             },
#             "quantityKind": {
#               "type": "string",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/Temperature"
#               ]
#             }
#           }
#         },
#         "Pressure": {
#           "type": "object",
#           "description": "The pressure within the reactor during deposition, typically in Torr.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "properties": {
#                 "numericValue": {
#                   "type": "number"
#                 },
#                 "unit": {
#                   "type": "object",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Pressure"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "enum": [
#                         "https://qudt.org/vocab/unit/TORR"
#                       ]
#                     }
#                   }
#                 }
#               }
#             },
#             "quantityKind": {
#               "type": "string",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/Pressure"
#               ]
#             }
#           }
#         },
#         "ThicknessControl": {
#           "type": "object",
#           "description": "Control and verification of material thickness per cycle.",
#           "properties": {
#             "GrowthPerCycle": {
#               "type": "object",
#               "description": "The amount of material deposited per cycle, typically measured in nm per cycle.",
#               "properties": {
#                 "quantityValue": {
#                   "type": "object",
#                   "properties": {
#                     "numericValue": {
#                       "type": "number"
#                     },
#                     "unit": {
#                       "type": "object",
#                       "properties": {
#                         "hasQuantityKind": {
#                           "type": "string",
#                           "enum": [
#                             "https://qudt.org/vocab/quantitykind/Length"
#                           ]
#                         },
#                         "sameAs": {
#                           "type": "string",
#                           "enum": [
#                             "https://qudt.org/vocab/unit/NM"
#                           ]
#                         }
#                       }
#                     }
#                   }
#                 },
#                 "quantityKind": {
#                   "type": "string",
#                   "enum": [
#                     "https://qudt.org/vocab/quantitykind/Length"
#                   ]
#                 }
#               }
#             },
#             "saturation": {
#               "type": "boolean",
#               "description": "Indicates if saturation conditions are achieved during dosing and purging."
#             },
#             "nucleationPeriod": {
#               "type": "object",
#               "description": "Initial growth behavior of the film during the first few ALD cycles, measured in cycles.",
#               "properties": {
#                 "quantityValue": {
#                   "type": "object",
#                   "properties": {
#                     "numericValue": {
#                       "type": "number"
#                     },
#                     "unit": {
#                       "type": "object",
#                       "properties": {
#                         "sameAs": {
#                           "type": "string",
#                           "enum": [
#                             "https://qudt.org/vocab/unit/CYCLE"
#                           ]
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             },
#             "DosingTime": {
#               "type": "object",
#               "properties": {
#                 "Precursor": {
#                   "type": "object",
#                   "description": "Time for dosing the precursor, measured in seconds.",
#                   "properties": {
#                     "quantityValue": {
#                       "type": "object",
#                       "properties": {
#                         "numericValue": {
#                           "type": "number"
#                         },
#                         "unit": {
#                           "type": "object",
#                           "properties": {
#                             "hasQuantityKind": {
#                               "type": "string",
#                               "enum": [
#                                 "https://qudt.org/vocab/quantitykind/Time"
#                               ]
#                             },
#                             "sameAs": {
#                               "type": "string",
#                               "enum": [
#                                 "https://qudt.org/vocab/unit/SEC"
#                               ]
#                             }
#                           }
#                         }
#                       }
#                     },
#                     "quantityKind": {
#                       "type": "string",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Time"
#                       ]
#                     }
#                   }
#                 },
#                 "CoReactant": {
#                   "type": "object",
#                   "description": "Time for dosing the co-reactant, measured in seconds.",
#                   "properties": {
#                     "quantityValue": {
#                       "type": "object",
#                       "properties": {
#                         "numericValue": {
#                           "type": "number"
#                         },
#                         "unit": {
#                           "type": "object",
#                           "properties": {
#                             "hasQuantityKind": {
#                               "type": "string",
#                               "enum": [
#                                 "https://qudt.org/vocab/quantitykind/Time"
#                               ]
#                             },
#                             "sameAs": {
#                               "type": "string",
#                               "enum": [
#                                 "https://qudt.org/vocab/unit/SEC"
#                               ]
#                             }
#                           }
#                         }
#                       }
#                     },
#                     "quantityKind": {
#                       "type": "string",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Time"
#                       ]
#                     }
#                   }
#                 }
#               }
#             },
#             "PurgeTime": {
#               "type": "object",
#               "properties": {
#                 "Precursor": {
#                   "type": "object",
#                   "description": "Time for purging the reactor chamber after precursor dosing, measured in seconds.",
#                   "properties": {
#                     "quantityValue": {
#                       "type": "object",
#                       "properties": {
#                         "numericValue": {
#                           "type": "number"
#                         },
#                         "unit": {
#                           "type": "object",
#                           "properties": {
#                             "hasQuantityKind": {
#                               "type": "string",
#                               "enum": [
#                                 "https://qudt.org/vocab/quantitykind/Time"
#                               ]
#                             },
#                             "sameAs": {
#                               "type": "string",
#                               "enum": [
#                                 "https://qudt.org/vocab/unit/SEC"
#                               ]
#                             }
#                           }
#                         }
#                       }
#                     },
#                     "quantityKind": {
#                       "type": "string",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Time"
#                       ]
#                     }
#                   }
#                 },
#                 "CoReactant": {
#                   "type": "object",
#                   "description": "Time for purging the reactor chamber after co-reactant dosing, measured in seconds.",
#                   "properties": {
#                     "quantityValue": {
#                       "type": "object",
#                       "properties": {
#                         "numericValue": {
#                           "type": "number"
#                         },
#                         "unit": {
#                           "type": "object",
#                           "properties": {
#                             "hasQuantityKind": {
#                               "type": "string",
#                               "enum": [
#                                 "https://qudt.org/vocab/quantitykind/Time"
#                               ]
#                             },
#                             "sameAs": {
#                               "type": "string",
#                               "enum": [
#                                 "https://qudt.org/vocab/unit/SEC"
#                               ]
#                             }
#                           }
#                         }
#                       }
#                     },
#                     "quantityKind": {
#                       "type": "string",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Time"
#                       ]
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     },
#     "MaterialProperties": {
#       "type": "object",
#       "description": "Assessment of the properties of the deposited film.",
#       "properties": {
#         "OpticalProperties": {
#           "type": "object",
#           "properties": {
#             "RefractiveIndex": {
#               "type": "number",
#               "description": "Refractive index of the film."
#             },
#             "AbsorptionCoefficient": {
#               "type": "number",
#               "description": "Optical absorption coefficient."
#             }
#           }
#         },
#         "ElectricalProperties": {
#           "type": "object",
#           "properties": {
#             "Resistivity": {
#               "type": "object",
#               "description": "Electrical resistivity of the film.",
#               "properties": {
#                 "quantityValue": {
#                   "type": "object",
#                   "properties": {
#                     "numericValue": {
#                       "type": "number"
#                     },
#                     "unit": {
#                       "type": "object",
#                       "properties": {
#                         "hasQuantityKind": {
#                           "type": "string",
#                           "enum": [
#                             "https://qudt.org/vocab/quantitykind/ElectricResistivity"
#                           ]
#                         },
#                         "sameAs": {
#                           "type": "string",
#                           "enum": [
#                             "https://qudt.org/vocab/unit/OHM_M"
#                           ]
#                         }
#                       }
#                     }
#                   }
#                 },
#                 "quantityKind": {
#                   "type": "string",
#                   "enum": [
#                     "https://qudt.org/vocab/quantitykind/ElectricResistivity"
#                   ]
#                 }
#               }
#             },
#             "CarrierDensity": {
#               "type": "number",
#               "description": "Carrier density in the film."
#             },
#             "Mobility": {
#               "type": "number",
#               "description": "Carrier mobility in the film."
#             }
#           }
#         },
#         "Uniformity": {
#           "type": "object",
#           "description": "Assessment of film thickness uniformity across large substrate areas.",
#           "properties": {
#             "Variation": {
#               "type": "object",
#               "description": "Permissible variation in film thickness, typically measured in percentage.",
#               "properties": {
#                 "quantityValue": {
#                   "type": "object",
#                   "properties": {
#                     "numericValue": {
#                       "type": "number"
#                     },
#                     "unit": {
#                       "type": "object",
#                       "properties": {
#                         "sameAs": {
#                           "type": "string",
#                           "enum": [
#                             "https://qudt.org/vocab/unit/PERCENT"
#                           ]
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         },
#         "Conformality": {
#           "type": "object",
#           "description": "Ability of the film to coat 3D structures uniformly.",
#           "properties": {
#             "AspectRatio": {
#               "type": "number",
#               "description": "Aspect ratio of the 3D structures used in testing conformality."
#             }
#           }
#         },
#         "ChemicalComposition": {
#           "type": "string",
#           "description": "Chemical composition of the deposited film."
#         },
#         "Crystallinity": {
#           "type": "string",
#           "description": "Describes whether the film is amorphous or crystalline."
#         },
#         "FilmDensity": {
#           "type": "object",
#           "description": "Density of the film, typically measured in g/cm3.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "properties": {
#                 "numericValue": {
#                   "type": "number"
#                 },
#                 "unit": {
#                   "type": "object",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Density"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "enum": [
#                         "https://qudt.org/vocab/unit/G-PER-CM3"
#                       ]
#                     }
#                   }
#                 }
#               }
#             },
#             "quantityKind": {
#               "type": "string",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/Density"
#               ]
#             }
#           }
#         }
#       }
#     },
#     "OtherAspects": {
#       "type": "object",
#       "description": "Other important aspects of the ALD process development such as safety and reproducibility.",
#       "properties": {
#         "Safety": {
#           "type": "string",
#           "description": "Safety considerations for handling chemicals and reaction products."
#         },
#         "FilmStability": {
#           "type": "boolean",
#           "description": "Whether the film remains stable under intended environmental conditions."
#         },
#         "Reproducibility": {
#           "type": "boolean",
#           "description": "Consistency of results in repeated experiments."
#         }
#       }
#     }
#   },
#   "required": [
#     "ALDSystem",
#     "ReactantSelection",
#     "ProcessParameters",
#     "MaterialProperties",
#     "OtherAspects"
#   ]
# }

# %% [markdown]
# ### 🌐 Ontology Grounding with QUDT Using Agentic Workflow <a id='agentic-grounding'></a>
#
# Here we use an agent-based pipeline to ground schema elements. The agent retrieves ontology candidates, reasons over matches, and validates outputs.

# %%
from schema_miner.ontology_grounding.agentic_qudt_grounding import agentic_qudt_grounding

# %%
# Large Language Model (LLM) to be used for Schema Extraction
llm_model_name = 'gpt-4o'

# Ground the schema with QUDT Ontology
process_schema = Path('../results1/Ideal Schema/Atomic-Layer-Deposition/experimental-ideal-schema.json')
results_file_path = Path("../results/qudt-grounded/Atomic-Layer-Deposition/experimental-schema")
schema = agentic_qudt_grounding(llm_model_name, process_schema, results_file_path, save_schema = True)

# %%
# Display the final Process Schema
logging.info(f'{ProcessConfig.Process_name} Schema:\n{json.dumps(schema, indent = 2)}')
# Out:
# 2025-08-31 18:30:55,061 - root - INFO - Atomic Layer Deposition Schema:
# {
#   "$schema": "http://json-schema.org/draft-07/schema#",
#   "title": "Atomic Layer Deposition (ALD) Process",
#   "description": "A schema representing the steps and parameters involved in setting up and characterizing an Atomic Layer Deposition process and the deposited film.",
#   "type": "object",
#   "properties": {
#     "ALDSystem": {
#       "type": "object",
#       "description": "Details about the ALD system used.",
#       "properties": {
#         "ALDMethod": {
#           "type": "string",
#           "description": "The specific ALD technique used, e.g., thermal ALD, plasma-enhanced ALD."
#         },
#         "MaterialDeposited": {
#           "type": "object",
#           "description": "The material being deposited, e.g., TiO2, Copper.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Mass"
#                       ],
#                       "sameAs": [
#                         "https://qudt.org/vocab/unit/GM",
#                         "https://qudt.org/vocab/unit/KiloGM"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/Mass"
#               ]
#             }
#           }
#         }
#       }
#     },
#     "ReactantSelection": {
#       "type": "object",
#       "description": "Selection of precursor and co-reactant based on their reactivity, volatility, and safety.",
#       "properties": {
#         "Precursor": {
#           "type": "object",
#           "description": "Chemical used as a precursor in the ALD process, e.g., tris(diethylamino)aluminum.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/ChemicalAffinity",
#                         "https://qudt.org/vocab/quantitykind/Acidity"
#                       ],
#                       "sameAs": [
#                         "https://qudt.org/vocab/unit/J-PER-MOL",
#                         "https://qudt.org/vocab/unit/PH"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/ChemicalAffinity",
#                 "https://qudt.org/vocab/quantitykind/Acidity"
#               ]
#             }
#           }
#         },
#         "CoReactant": {
#           "type": "object",
#           "description": "Chemical used as a co-reactant in the ALD process, e.g., water, hydrogen plasma.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/ChemicalAffinity"
#                       ],
#                       "sameAs": [
#                         "https://qudt.org/vocab/unit/J-PER-MOL"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/ChemicalAffinity"
#               ]
#             }
#           }
#         },
#         "CarrierGas": {
#           "type": "string",
#           "description": "Type of carrier gas used in the delivery of reactants."
#         }
#       }
#     },
#     "ProcessParameters": {
#       "type": "object",
#       "description": "Specific parameters under which the ALD process is carried out.",
#       "properties": {
#         "Reactor": {
#           "type": "object",
#           "description": "Type and details of the reactor used for the ALD process.",
#           "properties": {
#             "Name": {
#               "type": "string",
#               "description": "Name of the reactor."
#             },
#             "Manufacturer": {
#               "type": "string",
#               "description": "Manufacturer of the reactor."
#             }
#           }
#         },
#         "DeliveryMethod": {
#           "type": "string",
#           "description": "Method of delivering the precursor and co-reactant to the reaction chamber."
#         },
#         "Temperature": {
#           "type": "object",
#           "description": "The temperature at which deposition occurs, typically in \u00b0C.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Temperature"
#                       ],
#                       "sameAs": [
#                         "https://qudt.org/vocab/unit/DEG_C"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/Temperature"
#               ]
#             }
#           }
#         },
#         "Pressure": {
#           "type": "object",
#           "description": "The pressure within the reactor during deposition, typically in Torr.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Pressure"
#                       ],
#                       "sameAs": [
#                         "https://qudt.org/vocab/unit/ATM",
#                         "https://qudt.org/vocab/unit/BAR",
#                         "https://qudt.org/vocab/unit/TORR",
#                         "https://qudt.org/vocab/unit/PSI"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/Pressure"
#               ]
#             }
#           }
#         },
#         "ThicknessControl": {
#           "type": "object",
#           "description": "Control and verification of material thickness per cycle.",
#           "properties": {
#             "GrowthPerCycle": {
#               "type": "object",
#               "description": "The amount of material deposited per cycle, typically measured in nm per cycle.",
#               "properties": {
#                 "quantityValue": {
#                   "type": "object",
#                   "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#                   "properties": {
#                     "numericValue": {
#                       "type": "number",
#                       "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                     },
#                     "unit": {
#                       "type": "object",
#                       "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                       "properties": {
#                         "hasQuantityKind": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                           "enum": [
#                             "https://qudt.org/vocab/quantitykind/Length"
#                           ],
#                           "sameAs": [
#                             "https://qudt.org/vocab/unit/NanoM"
#                           ]
#                         },
#                         "sameAs": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                         }
#                       }
#                     }
#                   },
#                   "required": [
#                     "numericValue",
#                     "unit"
#                   ]
#                 },
#                 "quantityKind": {
#                   "type": "string",
#                   "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                   "enum": [
#                     "https://qudt.org/vocab/quantitykind/Length"
#                   ]
#                 }
#               }
#             },
#             "saturation": {
#               "type": "boolean",
#               "description": "Indicates if saturation conditions are achieved during dosing and purging."
#             },
#             "nucleationPeriod": {
#               "type": "object",
#               "description": "Initial growth behavior of the film during the first few ALD cycles, measured in cycles.",
#               "properties": {
#                 "quantityValue": {
#                   "type": "object",
#                   "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#                   "properties": {
#                     "numericValue": {
#                       "type": "number",
#                       "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                     },
#                     "unit": {
#                       "type": "object",
#                       "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                       "properties": {
#                         "hasQuantityKind": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                           "enum": [
#                             "http://qudt.org/vocab/quantitykind/Period",
#                             "http://qudt.org/vocab/quantitykind/Count"
#                           ],
#                           "sameAs": []
#                         },
#                         "sameAs": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                         }
#                       }
#                     }
#                   },
#                   "required": [
#                     "numericValue",
#                     "unit"
#                   ]
#                 },
#                 "quantityKind": {
#                   "type": "string",
#                   "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                   "enum": [
#                     "http://qudt.org/vocab/quantitykind/Period",
#                     "http://qudt.org/vocab/quantitykind/Count"
#                   ]
#                 }
#               }
#             },
#             "DosingTime": {
#               "type": "object",
#               "properties": {
#                 "Precursor": {
#                   "type": "object",
#                   "description": "Time for dosing the precursor, measured in seconds.",
#                   "properties": {
#                     "quantityValue": {
#                       "type": "object",
#                       "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#                       "properties": {
#                         "numericValue": {
#                           "type": "number",
#                           "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                         },
#                         "unit": {
#                           "type": "object",
#                           "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                           "properties": {
#                             "hasQuantityKind": {
#                               "type": "string",
#                               "format": "uri",
#                               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                               "enum": [
#                                 "https://qudt.org/vocab/quantitykind/Time"
#                               ],
#                               "sameAs": [
#                                 "https://qudt.org/vocab/unit/SEC"
#                               ]
#                             },
#                             "sameAs": {
#                               "type": "string",
#                               "format": "uri",
#                               "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                             }
#                           }
#                         }
#                       },
#                       "required": [
#                         "numericValue",
#                         "unit"
#                       ]
#                     },
#                     "quantityKind": {
#                       "type": "string",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Time"
#                       ]
#                     }
#                   }
#                 },
#                 "CoReactant": {
#                   "type": "object",
#                   "description": "Time for dosing the co-reactant, measured in seconds.",
#                   "properties": {
#                     "quantityValue": {
#                       "type": "object",
#                       "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#                       "properties": {
#                         "numericValue": {
#                           "type": "number",
#                           "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                         },
#                         "unit": {
#                           "type": "object",
#                           "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                           "properties": {
#                             "hasQuantityKind": {
#                               "type": "string",
#                               "format": "uri",
#                               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                               "enum": [
#                                 "https://qudt.org/vocab/quantitykind/Time"
#                               ],
#                               "sameAs": [
#                                 "https://qudt.org/vocab/unit/SEC"
#                               ]
#                             },
#                             "sameAs": {
#                               "type": "string",
#                               "format": "uri",
#                               "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                             }
#                           }
#                         }
#                       },
#                       "required": [
#                         "numericValue",
#                         "unit"
#                       ]
#                     },
#                     "quantityKind": {
#                       "type": "string",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Time"
#                       ]
#                     }
#                   }
#                 }
#               }
#             },
#             "PurgeTime": {
#               "type": "object",
#               "properties": {
#                 "Precursor": {
#                   "type": "object",
#                   "description": "Time for purging the reactor chamber after precursor dosing, measured in seconds.",
#                   "properties": {
#                     "quantityValue": {
#                       "type": "object",
#                       "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#                       "properties": {
#                         "numericValue": {
#                           "type": "number",
#                           "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                         },
#                         "unit": {
#                           "type": "object",
#                           "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                           "properties": {
#                             "hasQuantityKind": {
#                               "type": "string",
#                               "format": "uri",
#                               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                               "enum": [
#                                 "http://qudt.org/vocab/quantitykind/Time"
#                               ],
#                               "sameAs": [
#                                 "http://qudt.org/vocab/unit/SEC"
#                               ]
#                             },
#                             "sameAs": {
#                               "type": "string",
#                               "format": "uri",
#                               "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                             }
#                           }
#                         }
#                       },
#                       "required": [
#                         "numericValue",
#                         "unit"
#                       ]
#                     },
#                     "quantityKind": {
#                       "type": "string",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "http://qudt.org/vocab/quantitykind/Time"
#                       ]
#                     }
#                   }
#                 },
#                 "CoReactant": {
#                   "type": "object",
#                   "description": "Time for purging the reactor chamber after co-reactant dosing, measured in seconds.",
#                   "properties": {
#                     "quantityValue": {
#                       "type": "object",
#                       "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#                       "properties": {
#                         "numericValue": {
#                           "type": "number",
#                           "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                         },
#                         "unit": {
#                           "type": "object",
#                           "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                           "properties": {
#                             "hasQuantityKind": {
#                               "type": "string",
#                               "format": "uri",
#                               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                               "enum": [
#                                 "https://qudt.org/vocab/quantitykind/Time"
#                               ],
#                               "sameAs": [
#                                 "https://qudt.org/vocab/unit/SEC"
#                               ]
#                             },
#                             "sameAs": {
#                               "type": "string",
#                               "format": "uri",
#                               "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                             }
#                           }
#                         }
#                       },
#                       "required": [
#                         "numericValue",
#                         "unit"
#                       ]
#                     },
#                     "quantityKind": {
#                       "type": "string",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Time"
#                       ]
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     },
#     "MaterialProperties": {
#       "type": "object",
#       "description": "Assessment of the properties of the deposited film.",
#       "properties": {
#         "OpticalProperties": {
#           "type": "object",
#           "properties": {
#             "RefractiveIndex": {
#               "type": "object",
#               "description": "Refractive index of the film.",
#               "properties": {
#                 "quantityValue": {
#                   "type": "object",
#                   "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#                   "properties": {
#                     "numericValue": {
#                       "type": "number",
#                       "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                     },
#                     "unit": {
#                       "type": "object",
#                       "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                       "properties": {
#                         "hasQuantityKind": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                           "enum": [
#                             "https://qudt.org/vocab/quantitykind/RefractiveIndex"
#                           ],
#                           "sameAs": [
#                             "https://qudt.org/vocab/unit/UNITLESS"
#                           ]
#                         },
#                         "sameAs": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                         }
#                       }
#                     }
#                   },
#                   "required": [
#                     "numericValue",
#                     "unit"
#                   ]
#                 },
#                 "quantityKind": {
#                   "type": "string",
#                   "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                   "enum": [
#                     "https://qudt.org/vocab/quantitykind/RefractiveIndex"
#                   ]
#                 }
#               }
#             },
#             "AbsorptionCoefficient": {
#               "type": "object",
#               "description": "Optical absorption coefficient.",
#               "properties": {
#                 "quantityValue": {
#                   "type": "object",
#                   "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#                   "properties": {
#                     "numericValue": {
#                       "type": "number",
#                       "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                     },
#                     "unit": {
#                       "type": "object",
#                       "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                       "properties": {
#                         "hasQuantityKind": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                           "enum": [
#                             "https://qudt.org/vocab/quantitykind/LinearAbsorptionCoefficient"
#                           ],
#                           "sameAs": [
#                             "https://qudt.org/vocab/unit/PER-KiloM",
#                             "https://qudt.org/vocab/unit/PER-M",
#                             "https://qudt.org/vocab/unit/PER-MicroM",
#                             "https://qudt.org/vocab/unit/PER-MilliM",
#                             "https://qudt.org/vocab/unit/PER-NanoM",
#                             "https://qudt.org/vocab/unit/PER-PicoM"
#                           ]
#                         },
#                         "sameAs": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                         }
#                       }
#                     }
#                   },
#                   "required": [
#                     "numericValue",
#                     "unit"
#                   ]
#                 },
#                 "quantityKind": {
#                   "type": "string",
#                   "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                   "enum": [
#                     "https://qudt.org/vocab/quantitykind/LinearAbsorptionCoefficient"
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         "ElectricalProperties": {
#           "type": "object",
#           "properties": {
#             "Resistivity": {
#               "type": "object",
#               "description": "Electrical resistivity of the film.",
#               "properties": {
#                 "quantityValue": {
#                   "type": "object",
#                   "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#                   "properties": {
#                     "numericValue": {
#                       "type": "number",
#                       "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                     },
#                     "unit": {
#                       "type": "object",
#                       "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                       "properties": {
#                         "hasQuantityKind": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                           "enum": [
#                             "https://qudt.org/vocab/quantitykind/Resistivity"
#                           ],
#                           "sameAs": [
#                             "https://qudt.org/vocab/unit/OHM_M"
#                           ]
#                         },
#                         "sameAs": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                         }
#                       }
#                     }
#                   },
#                   "required": [
#                     "numericValue",
#                     "unit"
#                   ]
#                 },
#                 "quantityKind": {
#                   "type": "string",
#                   "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                   "enum": [
#                     "https://qudt.org/vocab/quantitykind/Resistivity"
#                   ]
#                 }
#               }
#             },
#             "CarrierDensity": {
#               "type": "object",
#               "description": "Carrier density in the film.",
#               "properties": {
#                 "quantityValue": {
#                   "type": "object",
#                   "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#                   "properties": {
#                     "numericValue": {
#                       "type": "number",
#                       "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                     },
#                     "unit": {
#                       "type": "object",
#                       "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                       "properties": {
#                         "hasQuantityKind": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                           "enum": [
#                             "https://qudt.org/vocab/quantitykind/ElectricChargeVolumeDensity"
#                           ],
#                           "sameAs": [
#                             "https://qudt.org/vocab/unit/C-PER-M3",
#                             "https://qudt.org/vocab/unit/A-HR-PER-M3"
#                           ]
#                         },
#                         "sameAs": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                         }
#                       }
#                     }
#                   },
#                   "required": [
#                     "numericValue",
#                     "unit"
#                   ]
#                 },
#                 "quantityKind": {
#                   "type": "string",
#                   "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                   "enum": [
#                     "https://qudt.org/vocab/quantitykind/ElectricChargeVolumeDensity"
#                   ]
#                 }
#               }
#             },
#             "Mobility": {
#               "type": "object",
#               "description": "Carrier mobility in the film.",
#               "properties": {
#                 "quantityValue": {
#                   "type": "object",
#                   "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#                   "properties": {
#                     "numericValue": {
#                       "type": "number",
#                       "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                     },
#                     "unit": {
#                       "type": "object",
#                       "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                       "properties": {
#                         "hasQuantityKind": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                           "enum": [
#                             "https://qudt.org/vocab/quantitykind/Mobility"
#                           ],
#                           "sameAs": [
#                             "https://qudt.org/vocab/unit/CentiM2-PER-V-SEC",
#                             "https://qudt.org/vocab/unit/M2-PER-V-SEC"
#                           ]
#                         },
#                         "sameAs": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                         }
#                       }
#                     }
#                   },
#                   "required": [
#                     "numericValue",
#                     "unit"
#                   ]
#                 },
#                 "quantityKind": {
#                   "type": "string",
#                   "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                   "enum": [
#                     "https://qudt.org/vocab/quantitykind/Mobility"
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         "Uniformity": {
#           "type": "object",
#           "description": "Assessment of film thickness uniformity across large substrate areas.",
#           "properties": {
#             "Variation": {
#               "type": "object",
#               "description": "Permissible variation in film thickness, typically measured in percentage.",
#               "properties": {
#                 "quantityValue": {
#                   "type": "object",
#                   "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#                   "properties": {
#                     "numericValue": {
#                       "type": "number",
#                       "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                     },
#                     "unit": {
#                       "type": "object",
#                       "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                       "properties": {
#                         "hasQuantityKind": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                           "enum": [
#                             "https://qudt.org/vocab/quantitykind/Thickness",
#                             "https://qudt.org/vocab/quantitykind/DimensionlessRatio"
#                           ],
#                           "sameAs": [
#                             "https://qudt.org/vocab/unit/PERCENT"
#                           ]
#                         },
#                         "sameAs": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                         }
#                       }
#                     }
#                   },
#                   "required": [
#                     "numericValue",
#                     "unit"
#                   ]
#                 },
#                 "quantityKind": {
#                   "type": "string",
#                   "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                   "enum": [
#                     "https://qudt.org/vocab/quantitykind/Thickness",
#                     "https://qudt.org/vocab/quantitykind/DimensionlessRatio"
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         "Conformality": {
#           "type": "object",
#           "description": "Ability of the film to coat 3D structures uniformly.",
#           "properties": {
#             "AspectRatio": {
#               "type": "object",
#               "description": "Aspect ratio of the 3D structures used in testing conformality.",
#               "properties": {
#                 "quantityValue": {
#                   "type": "object",
#                   "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#                   "properties": {
#                     "numericValue": {
#                       "type": "number",
#                       "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                     },
#                     "unit": {
#                       "type": "object",
#                       "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                       "properties": {
#                         "hasQuantityKind": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                           "enum": [
#                             "http://qudt.org/3.1.0/vocab/quantitykind#DimensionlessRatio"
#                           ],
#                           "sameAs": []
#                         },
#                         "sameAs": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                         }
#                       }
#                     }
#                   },
#                   "required": [
#                     "numericValue",
#                     "unit"
#                   ]
#                 },
#                 "quantityKind": {
#                   "type": "string",
#                   "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                   "enum": [
#                     "http://qudt.org/3.1.0/vocab/quantitykind#DimensionlessRatio"
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         "ChemicalComposition": {
#           "type": "object",
#           "description": "Chemical composition of the deposited film.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/MassFraction",
#                         "https://qudt.org/vocab/quantitykind/MoleFraction"
#                       ],
#                       "sameAs": []
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/MassFraction",
#                 "https://qudt.org/vocab/quantitykind/MoleFraction"
#               ]
#             }
#           }
#         },
#         "Crystallinity": {
#           "type": "string",
#           "description": "Describes whether the film is amorphous or crystalline."
#         },
#         "FilmDensity": {
#           "type": "object",
#           "description": "Density of the film, typically measured in g/cm3.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/MassDensity",
#                         "https://qudt.org/vocab/quantitykind/Density"
#                       ],
#                       "sameAs": [
#                         "https://qudt.org/vocab/unit/GM-PER-CentiM3",
#                         "https://qudt.org/vocab/unit/SLUG-PER-FT3",
#                         "https://qudt.org/vocab/unit/TONNE-PER-M3",
#                         "https://qudt.org/vocab/unit/TON_LONG-PER-YD3",
#                         "https://qudt.org/vocab/unit/TON_Metric-PER-M3",
#                         "https://qudt.org/vocab/unit/TON_SHORT-PER-YD3",
#                         "https://qudt.org/vocab/unit/TON_UK-PER-YD3",
#                         "https://qudt.org/vocab/unit/TON_US-PER-YD3"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/MassDensity",
#                 "https://qudt.org/vocab/quantitykind/Density"
#               ]
#             }
#           }
#         }
#       }
#     },
#     "OtherAspects": {
#       "type": "object",
#       "description": "Other important aspects of the ALD process development such as safety and reproducibility.",
#       "properties": {
#         "Safety": {
#           "type": "string",
#           "description": "Safety considerations for handling chemicals and reaction products."
#         },
#         "FilmStability": {
#           "type": "object",
#           "description": "Whether the film remains stable under intended environmental conditions.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [],
#                       "sameAs": []
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": []
#             }
#           }
#         },
#         "Reproducibility": {
#           "type": "boolean",
#           "description": "Consistency of results in repeated experiments."
#         }
#       }
#     }
#   },
#   "required": [
#     "ALDSystem",
#     "ReactantSelection",
#     "ProcessParameters",
#     "MaterialProperties",
#     "OtherAspects"
#   ]
# }
