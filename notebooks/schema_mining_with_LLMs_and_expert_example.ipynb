# %% [markdown]
# ## 📄🔍 A Human-in-the-Loop Workflow for Scientific Schema Mining with Large Language Models
#
# This notebook demonstrates how to use the **Schema-Miner** package to discover and refine structured schemas from scientific literature with the help of **large language models (LLMs)** and **expert feedback**.
#
# Schemas help turn **unstructured scientific text** (papers, specifications) into structured, machine-readable representations. With Schema-Miner, you can:
# - Automatically extract candidate schemas from domain documents
# - Iteratively refine schemas with expert feedback
# - Validate schemas against a wider corpus of literature
#
# We’ll walk through the process step by step, using **Atomic Layer Deposition (ALD)** as an example domain.

# %% [markdown]
# ## 🔎 Workflow Overview
#
# The schema mining workflow has **three main stages**:
#
# 1. **Initial Schema Mining** → Generate an initial schema from a process specification using an LLM
# 2. **Preliminary Schema Refinement** → Incorporate expert feedback and a small curated corpus of scientific papers
# 3. **Finalize Schema Refinement** → Validate against a bigger corpus
#
# A complete workflow diagram and detailed explanation can be found [here](../README.md).

# %% [markdown]
# **Overview**
# 1. [Intalling Schema_miner](#installing-schema_miner)
# 2. [Configuration](#configuration)
# 3. [Stage 01: Initial Schema Mining](#initial-schema-mining)
# 4. [Stage 02: Preliminary Schema Refinement](#pre-schema-refinement)
# 5. [Stage 03: Finalize Schema Refinement](#finalize-schema-refinement)

# %% [markdown]
# ### 🗂️ Installing Schema_miner <a id='installing-schema-miner'></a>
#
# You can install schema-miner via **pip**:
#
# ```bash
# pip install -i https://test.pypi.org/simple/ schema-miner
# ```
#
# Or directly from GitHub (latest development version):
#
# ```bash
# pip install git+https://github.com/sciknoworg/schema-miner.git
# ```

# %% [markdown]
# ### 🛠️ Configuration <a id='configuration'></a>
#
# Before running schema-miner, configure your environment.

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Configure logging
import logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s"
)

# %%
from schema_miner.config.envConfig import EnvConfig
EnvConfig.OPENAI_api_key = '<insert-your-openai-key>'
EnvConfig.OPENAI_organization_id = '<insert-your-openi-organization-id>'

# %% [markdown]
# ### 📂 Data Setup
#
# Before running schema-miner, we need to tell schema-miner where to find:
#
# - **Domain specification document(s)** → used for initial schema mining
# - **Curated corpus** (high-quality literature) → used for refinement
# - **Broader corpus** (larger set of papers) → used for final validation
#
# Update the paths below according to your setup.

# %%
# Process Specification for Stage 1
process_specification_filepath = '../data/stage-1/Atomic-Layer-Deposition/Experimental-Usecase'
process_specification_filename = 'ALD-Process-Development.pdf'

# Small curated corpus of scientific papers
scientific_paper_stage2_dir = '../data/stage-2/Atomic-Layer-Deposition/research-papers/experimental-usecase'

# Bigger corpus of scientific papers
scientific_paper_stage3_dir = '../data/stage-3/Atomic-Layer-Deposition/research-papers/experimental_usecase'

# %% [markdown]
# ### 🧪 Process Setup
#
# In this notebook, we demonstrate schema mining on the domain of **Atomic Layer Deposition (ALD)**.
# This process involves alternating exposures of a substrate to chemical precursors, enabling precise thin-film growth at the atomic scale.
#
# > 💡 To adapt this notebook to a new domain, replace the domain name/description here and update the input literature paths in the Data Setup section.

# %%
# Add process name and process description whose schema have to be extracted 
from schema_miner.config.processConfig import ProcessConfig
ProcessConfig.Process_name = "Atomic Layer Deposition"
ProcessConfig.Process_description = "An ALD process involves a series of controlled chemical reactions used to deposit thin films on a surface at an atomic level"

# %% [markdown]
# ### ⚙️ Stage 01: Initial Schema Mining <a id='initial-schema-mining'></a>

# %% [markdown]
# During Stage 1, we task the LLM with designing an initial JSON schema based on a process specification document that contains limited information about an ALD process. For this example, we have used OpenAI's GPT-4 language model, using a prompt template as demonstrated [here](../schema_miner/prompts/schema_extraction/prompt_template1.py).

# %%
import json
from pathlib import Path
from schema_miner.pdf_text_extractor import pdf_text_extractor
from schema_miner.schema_extractor.extract_schema import extract_schema_stage1

# %%
# Large Language Model (LLM) to be used for Schema Extraction
llm_model_name = 'gpt-4o'

results_file_path = Path("../results/stage-1/Atomic-Layer-Deposition/experimental-schema")
process_specification = pdf_text_extractor(process_specification_filepath, process_specification_filename, return_text = True)
schema = extract_schema_stage1(llm_model_name, process_specification, results_file_path, save_schema = True)

# %%
print(f'{ProcessConfig.Process_name} Schema:\n{json.dumps(schema, indent = 2)}')
# Out:
# Atomic Layer Deposition Schema:
# {
#   "$schema": "http://json-schema.org/draft-07/schema#",
#   "title": "Atomic Layer Deposition Process",
#   "type": "object",
#   "properties": {
#     "reactantSelection": {
#       "type": "object",
#       "description": "Details about the precursor and co-reactant used in the ALD process.",
#       "properties": {
#         "precursor": {
#           "type": "string",
#           "description": "The chemical compound used as the precursor in the ALD process."
#         },
#         "coReactant": {
#           "type": "string",
#           "description": "The chemical compound used as the co-reactant in the ALD process."
#         },
#         "deliveryMethod": {
#           "type": "string",
#           "enum": [
#             "vapor drawn",
#             "carrier gas assisted",
#             "bubbling"
#           ],
#           "description": "Method of delivering the precursor to the chamber."
#         }
#       },
#       "required": [
#         "precursor",
#         "coReactant"
#       ]
#     },
#     "chemicalComposition": {
#       "type": "object",
#       "description": "Information about the chemical composition of the deposited film.",
#       "properties": {
#         "expectedElements": {
#           "type": "array",
#           "items": {
#             "type": "string"
#           },
#           "description": "List of elements expected in the deposited film."
#         },
#         "analysisMethods": {
#           "type": "array",
#           "items": {
#             "type": "string",
#             "enum": [
#               "XPS",
#               "RBS",
#               "four-point probe",
#               "refractive index"
#             ]
#           },
#           "description": "Methods used to analyze the chemical composition."
#         }
#       }
#     },
#     "thicknessControl": {
#       "type": "object",
#       "description": "Parameters related to the control of film thickness.",
#       "properties": {
#         "growthPerCycle": {
#           "type": "number",
#           "description": "Growth per cycle (GPC) in nanometers (nm).",
#           "units": "nm"
#         },
#         "measurementMethods": {
#           "type": "array",
#           "items": {
#             "type": "string",
#             "enum": [
#               "spectroscopic ellipsometry",
#               "RBS",
#               "quartz-crystal microbalance"
#             ]
#           },
#           "description": "Methods used to measure film thickness."
#         }
#       }
#     },
#     "saturation": {
#       "type": "object",
#       "description": "Details about the saturation behavior of the ALD process.",
#       "properties": {
#         "precursorDosingTime": {
#           "type": "number",
#           "description": "Time for precursor dosing in seconds.",
#           "units": "s"
#         },
#         "precursorPurgeTime": {
#           "type": "number",
#           "description": "Time for precursor purge in seconds.",
#           "units": "s"
#         },
#         "coReactantExposureTime": {
#           "type": "number",
#           "description": "Time for co-reactant exposure in seconds.",
#           "units": "s"
#         },
#         "coReactantPurgeTime": {
#           "type": "number",
#           "description": "Time for co-reactant purge in seconds.",
#           "units": "s"
#         }
#       }
#     },
#     "materialProperties": {
#       "type": "object",
#       "description": "Properties of the deposited material.",
#       "properties": {
#         "opticalProperties": {
#           "type": "object",
#           "properties": {
#             "refractiveIndex": {
#               "type": "number",
#               "description": "Refractive index of the material."
#             },
#             "absorptionCoefficient": {
#               "type": "number",
#               "description": "Absorption coefficient of the material."
#             }
#           }
#         },
#         "electricalProperties": {
#           "type": "object",
#           "properties": {
#             "resistivity": {
#               "type": "number",
#               "description": "Resistivity of the material in ohm-meter (\u03a9\u00b7m).",
#               "units": "\u03a9\u00b7m"
#             },
#             "carrierDensity": {
#               "type": "number",
#               "description": "Carrier density in the material per cubic centimeter (cm^-3).",
#               "units": "cm^-3"
#             },
#             "mobility": {
#               "type": "number",
#               "description": "Carrier mobility in the material in square centimeters per volt-second (cm^2/V\u00b7s).",
#               "units": "cm^2/V\u00b7s"
#             }
#           }
#         },
#         "morphology": {
#           "type": "object",
#           "properties": {
#             "roughness": {
#               "type": "number",
#               "description": "Surface roughness in nanometers (nm).",
#               "units": "nm"
#             },
#             "crystallinity": {
#               "type": "string",
#               "description": "Crystallinity of the material, e.g., amorphous, polycrystalline."
#             }
#           }
#         }
#       }
#     },
#     "temperatureDependence": {
#       "type": "object",
#       "description": "Effects of temperature on the ALD process.",
#       "properties": {
#         "temperatureRange": {
#           "type": "array",
#           "items": {
#             "type": "number"
#           },
#           "description": "Range of substrate temperatures in degrees Celsius (\u00b0C).",
#           "units": "\u00b0C"
#         },
#         "ALDWindow": {
#           "type": "object",
#           "properties": {
#             "lowerBound": {
#               "type": "number",
#               "description": "Lower bound of the ALD window in degrees Celsius (\u00b0C).",
#               "units": "\u00b0C"
#             },
#             "upperBound": {
#               "type": "number",
#               "description": "Upper bound of the ALD window in degrees Celsius (\u00b0C).",
#               "units": "\u00b0C"
#             }
#           }
#         }
#       }
#     },
#     "uniformity": {
#       "type": "object",
#       "description": "Uniformity of the film over large area substrates.",
#       "properties": {
#         "thicknessVariation": {
#           "type": "number",
#           "description": "Variation in film thickness across the substrate in percentage (%).",
#           "units": "%"
#         }
#       }
#     },
#     "conformality": {
#       "type": "object",
#       "description": "Conformality of the ALD film on 3D structures.",
#       "properties": {
#         "aspectRatio": {
#           "type": "number",
#           "description": "Aspect ratio of the 3D structures.",
#           "units": "ratio"
#         },
#         "thicknessRatio": {
#           "type": "number",
#           "description": "Ratio of film thickness at different positions in the trench relative to the top.",
#           "units": "ratio"
#         }
#       }
#     },
#     "nucleationBehavior": {
#       "type": "object",
#       "description": "Initial growth behavior of the film during the ALD process.",
#       "properties": {
#         "initialGrowthMode": {
#           "type": "string",
#           "enum": [
#             "linear",
#             "accelerated",
#             "delayed"
#           ],
#           "description": "Initial growth mode of the film."
#         }
#       }
#     },
#     "otherAspects": {
#       "type": "object",
#       "description": "Other important aspects of the ALD process.",
#       "properties": {
#         "safety": {
#           "type": "boolean",
#           "description": "Indicates if safety measures are in place for the chemicals and process."
#         },
#         "filmStability": {
#           "type": "boolean",
#           "description": "Indicates if the film is stable over time and under environmental conditions."
#         },
#         "reproducibility": {
#           "type": "boolean",
#           "description": "Indicates if the process is reproducible with consistent results."
#         },
#         "precursorConsumption": {
#           "type": "number",
#           "description": "Efficiency of precursor usage in the process.",
#           "units": "mol"
#         },
#         "precursorStability": {
#           "type": "boolean",
#           "description": "Indicates if the precursor remains stable over time and under process conditions."
#         },
#         "literatureComparison": {
#           "type": "boolean",
#           "description": "Indicates if the results are consistent with existing literature."
#         },
#         "devicePerformance": {
#           "type": "boolean",
#           "description": "Indicates if the film performs well in a device application."
#         }
#       }
#     }
#   },
#   "required": [
#     "reactantSelection",
#     "chemicalComposition",
#     "thicknessControl",
#     "saturation",
#     "materialProperties",
#     "temperatureDependence",
#     "uniformity",
#     "conformality",
#     "nucleationBehavior",
#     "otherAspects"
#   ]
# }

# %%
expert_feedback_stage1 = 'The reactivity should be mentioned either at the process conditions or film properties. It’s the result of deposition under specific conditions not a standard property of the precursor or co-reactant.'

# %% [markdown]
# ### 🔄 Stage 02: Preliminary Schema Refinement <a id='pre-schema-refinement'></a>

# %% [markdown]
# During Stage 2, the initial JSON schema from Stage 1 is further refined using a curated dataset of scientific literature related to the ALD process, compiled by domain experts. This stage follows an iterative approach, incorporating expert feedback into each schema generated by the LLM. Here in this notebook, we have used only one expert's feedback to demostrate how it can be incorporated into the workflow. The prompt used for this stage is provided [here](../schema_miner/prompts/schema_extraction/prompt_template2.py)

# %%
from schema_miner.schema_extractor.extract_schema import extract_schema_stage2
    
schema = Path("../results/stage-1/Atomic-Layer-Deposition/experimental-schema/gpt-4o.json")
results_file_path = Path("../results/stage-2/Atomic-Layer-Deposition/experimental-schema")
scientific_paper = pdf_text_extractor(scientific_paper_stage2_dir, '1 Groner et al.pdf', return_text = True)
schema = extract_schema_stage2(llm_model_name, schema, expert_feedback_stage1, scientific_paper, results_file_path, save_schema = True)

# %%
print(f'{ProcessConfig.Process_name} Schema:\n{json.dumps(schema, indent = 2)}')
# Out:
# Atomic Layer Deposition Schema:
# {
#   "$schema": "http://json-schema.org/draft-07/schema#",
#   "title": "Atomic Layer Deposition Process",
#   "type": "object",
#   "properties": {
#     "reactantSelection": {
#       "type": "object",
#       "description": "Details about the precursor and co-reactant used in the ALD process.",
#       "properties": {
#         "precursor": {
#           "type": "string",
#           "description": "The chemical compound used as the precursor in the ALD process."
#         },
#         "coReactant": {
#           "type": "string",
#           "description": "The chemical compound used as the co-reactant in the ALD process."
#         },
#         "deliveryMethod": {
#           "type": "string",
#           "enum": [
#             "vapor drawn",
#             "carrier gas assisted",
#             "bubbling"
#           ],
#           "description": "Method of delivering the precursor to the chamber."
#         },
#         "reactorType": {
#           "type": "string",
#           "description": "Type of reactor used for the ALD process, e.g., viscous-flow reactor."
#         }
#       },
#       "required": [
#         "precursor",
#         "coReactant"
#       ]
#     },
#     "chemicalComposition": {
#       "type": "object",
#       "description": "Information about the chemical composition of the deposited film.",
#       "properties": {
#         "expectedElements": {
#           "type": "array",
#           "items": {
#             "type": "string"
#           },
#           "description": "List of elements expected in the deposited film."
#         },
#         "analysisMethods": {
#           "type": "array",
#           "items": {
#             "type": "string",
#             "enum": [
#               "XPS",
#               "RBS",
#               "four-point probe",
#               "refractive index"
#             ]
#           },
#           "description": "Methods used to analyze the chemical composition."
#         }
#       }
#     },
#     "thicknessControl": {
#       "type": "object",
#       "description": "Parameters related to the control of film thickness.",
#       "properties": {
#         "growthPerCycle": {
#           "type": "number",
#           "description": "Growth per cycle (GPC) in nanometers (nm).",
#           "units": "nm"
#         },
#         "measurementMethods": {
#           "type": "array",
#           "items": {
#             "type": "string",
#             "enum": [
#               "spectroscopic ellipsometry",
#               "RBS",
#               "quartz-crystal microbalance"
#             ]
#           },
#           "description": "Methods used to measure film thickness."
#         }
#       }
#     },
#     "saturation": {
#       "type": "object",
#       "description": "Details about the saturation behavior of the ALD process.",
#       "properties": {
#         "precursorDosingTime": {
#           "type": "number",
#           "description": "Time for precursor dosing in seconds.",
#           "units": "s"
#         },
#         "precursorPurgeTime": {
#           "type": "number",
#           "description": "Time for precursor purge in seconds.",
#           "units": "s"
#         },
#         "coReactantExposureTime": {
#           "type": "number",
#           "description": "Time for co-reactant exposure in seconds.",
#           "units": "s"
#         },
#         "coReactantPurgeTime": {
#           "type": "number",
#           "description": "Time for co-reactant purge in seconds.",
#           "units": "s"
#         }
#       }
#     },
#     "materialProperties": {
#       "type": "object",
#       "description": "Properties of the deposited material.",
#       "properties": {
#         "opticalProperties": {
#           "type": "object",
#           "properties": {
#             "refractiveIndex": {
#               "type": "number",
#               "description": "Refractive index of the material."
#             },
#             "absorptionCoefficient": {
#               "type": "number",
#               "description": "Absorption coefficient of the material."
#             }
#           }
#         },
#         "electricalProperties": {
#           "type": "object",
#           "properties": {
#             "resistivity": {
#               "type": "number",
#               "description": "Resistivity of the material in ohm-meter (\u03a9\u00b7m).",
#               "units": "\u03a9\u00b7m"
#             },
#             "carrierDensity": {
#               "type": "number",
#               "description": "Carrier density in the material per cubic centimeter (cm^-3).",
#               "units": "cm^-3"
#             },
#             "mobility": {
#               "type": "number",
#               "description": "Carrier mobility in the material in square centimeters per volt-second (cm^2/V\u00b7s).",
#               "units": "cm^2/V\u00b7s"
#             }
#           }
#         },
#         "morphology": {
#           "type": "object",
#           "properties": {
#             "roughness": {
#               "type": "number",
#               "description": "Surface roughness in nanometers (nm).",
#               "units": "nm"
#             },
#             "crystallinity": {
#               "type": "string",
#               "description": "Crystallinity of the material, e.g., amorphous, polycrystalline."
#             }
#           }
#         },
#         "density": {
#           "type": "number",
#           "description": "Density of the deposited film in grams per cubic centimeter (g/cm^3).",
#           "units": "g/cm^3"
#         },
#         "gasDiffusionBarrier": {
#           "type": "boolean",
#           "description": "Indicates if the film acts as a gas diffusion barrier."
#         }
#       }
#     },
#     "temperatureDependence": {
#       "type": "object",
#       "description": "Effects of temperature on the ALD process.",
#       "properties": {
#         "temperatureRange": {
#           "type": "array",
#           "items": {
#             "type": "number"
#           },
#           "description": "Range of substrate temperatures in degrees Celsius (\u00b0C).",
#           "units": "\u00b0C"
#         },
#         "ALDWindow": {
#           "type": "object",
#           "properties": {
#             "lowerBound": {
#               "type": "number",
#               "description": "Lower bound of the ALD window in degrees Celsius (\u00b0C).",
#               "units": "\u00b0C"
#             },
#             "upperBound": {
#               "type": "number",
#               "description": "Upper bound of the ALD window in degrees Celsius (\u00b0C).",
#               "units": "\u00b0C"
#             }
#           }
#         },
#         "lowTemperatureCapability": {
#           "type": "boolean",
#           "description": "Indicates if the ALD process can be performed at low temperatures (below 100\u00b0C)."
#         }
#       }
#     },
#     "uniformity": {
#       "type": "object",
#       "description": "Uniformity of the film over large area substrates.",
#       "properties": {
#         "thicknessVariation": {
#           "type": "number",
#           "description": "Variation in film thickness across the substrate in percentage (%).",
#           "units": "%"
#         }
#       }
#     },
#     "conformality": {
#       "type": "object",
#       "description": "Conformality of the ALD film on 3D structures.",
#       "properties": {
#         "aspectRatio": {
#           "type": "number",
#           "description": "Aspect ratio of the 3D structures.",
#           "units": "ratio"
#         },
#         "thicknessRatio": {
#           "type": "number",
#           "description": "Ratio of film thickness at different positions in the trench relative to the top.",
#           "units": "ratio"
#         }
#       }
#     },
#     "nucleationBehavior": {
#       "type": "object",
#       "description": "Initial growth behavior of the film during the ALD process.",
#       "properties": {
#         "initialGrowthMode": {
#           "type": "string",
#           "enum": [
#             "linear",
#             "accelerated",
#             "delayed"
#           ],
#           "description": "Initial growth mode of the film."
#         }
#       }
#     },
#     "otherAspects": {
#       "type": "object",
#       "description": "Other important aspects of the ALD process.",
#       "properties": {
#         "safety": {
#           "type": "boolean",
#           "description": "Indicates if safety measures are in place for the chemicals and process."
#         },
#         "filmStability": {
#           "type": "boolean",
#           "description": "Indicates if the film is stable over time and under environmental conditions."
#         },
#         "reproducibility": {
#           "type": "boolean",
#           "description": "Indicates if the process is reproducible with consistent results."
#         },
#         "precursorConsumption": {
#           "type": "number",
#           "description": "Efficiency of precursor usage in the process.",
#           "units": "mol"
#         },
#         "precursorStability": {
#           "type": "boolean",
#           "description": "Indicates if the precursor remains stable over time and under process conditions."
#         },
#         "literatureComparison": {
#           "type": "boolean",
#           "description": "Indicates if the results are consistent with existing literature."
#         },
#         "devicePerformance": {
#           "type": "boolean",
#           "description": "Indicates if the film performs well in a device application."
#         }
#       }
#     }
#   },
#   "required": [
#     "reactantSelection",
#     "chemicalComposition",
#     "thicknessControl",
#     "saturation",
#     "materialProperties",
#     "temperatureDependence",
#     "uniformity",
#     "conformality",
#     "nucleationBehavior",
#     "otherAspects"
#   ]
# }

# %%
expert_feedback_stage2 = '1. Remove the reactor property in the additional details and include this in the reactor design property in the process conditions unit under the reactor name.\n2. Bubblertemperatures: merge it with the precursor temperature property under the BubblerTemperature name in the precursor unit.\n3. Substrate type and substrate units should be merged under the Substrate name'

# %% [markdown]
# ### ✅ Stage 03: Finalize Schema Refinement <a id='finalize-schema-refinement'></a>

# %% [markdown]
# Similar to Stage 2, Stage 3 follows the same workflow and uses the same approach, with the key difference being the use of a larger corpus of scientific literature related to the ALD process. The goal of this stage is to provide the LLM with a broader perspective and more comprehensive information about the target process. The prompt used for this stage is provided [here](../schema_miner/prompts/schema_extraction/prompt_template3.py)

# %%
from schema_miner.schema_extractor.extract_schema import extract_schema_stage3
    
schema = Path("../results/test/stage-2/Atomic-Layer-Deposition/experimental-schema/gpt-4o.json")
results_file_path = Path("../results/stage-3/Atomic-Layer-Deposition/experimental-schema")
scientific_paper = pdf_text_extractor(scientific_paper_stage3_dir, '1-Mattinen et al.pdf', return_text = True)
schema = extract_schema_stage3(llm_model_name, schema, expert_feedback_stage2, scientific_paper, results_file_path, save_schema = True)

# %%
print(f'{ProcessConfig.Process_name} Schema:\n{json.dumps(schema, indent = 2)}')
# Out:
# Atomic Layer Deposition Schema:
# {
#   "$schema": "http://json-schema.org/draft-07/schema#",
#   "title": "Atomic Layer Deposition Process",
#   "type": "object",
#   "properties": {
#     "processConditions": {
#       "type": "object",
#       "description": "Conditions under which the ALD process is conducted.",
#       "properties": {
#         "temperature": {
#           "type": "number",
#           "description": "Temperature range for the ALD process in degrees Celsius.",
#           "minimum": 75,
#           "maximum": 400,
#           "unit": "\u00b0C"
#         },
#         "pressure": {
#           "type": "number",
#           "description": "Pressure during the ALD process in mbar.",
#           "unit": "mbar"
#         },
#         "reactor": {
#           "type": "object",
#           "description": "Details about the reactor used in the ALD process.",
#           "properties": {
#             "reactorName": {
#               "type": "string",
#               "description": "Name or model of the reactor."
#             },
#             "design": {
#               "type": "string",
#               "description": "Design specifics of the reactor."
#             }
#           }
#         }
#       }
#     },
#     "precursor": {
#       "type": "object",
#       "description": "Details about the precursors used in the ALD process.",
#       "properties": {
#         "bubblerTemperature": {
#           "type": "number",
#           "description": "Temperature of the bubbler for precursor delivery.",
#           "unit": "\u00b0C"
#         },
#         "precursorType": {
#           "type": "string",
#           "description": "Type of precursor used in the process."
#         }
#       }
#     },
#     "substrate": {
#       "type": "object",
#       "description": "Details about the substrate used in the ALD process.",
#       "properties": {
#         "type": {
#           "type": "string",
#           "description": "Type of substrate used, e.g., sapphire, mica."
#         },
#         "orientation": {
#           "type": "string",
#           "description": "Orientation of the substrate, e.g., (0001)."
#         },
#         "size": {
#           "type": "object",
#           "description": "Dimensions of the substrate.",
#           "properties": {
#             "width": {
#               "type": "number",
#               "description": "Width of the substrate in cm.",
#               "unit": "cm"
#             },
#             "height": {
#               "type": "number",
#               "description": "Height of the substrate in cm.",
#               "unit": "cm"
#             }
#           }
#         }
#       }
#     },
#     "filmProperties": {
#       "type": "object",
#       "description": "Properties of the film deposited during the ALD process.",
#       "properties": {
#         "material": {
#           "type": "string",
#           "description": "Material of the film, e.g., HfS2, MoS2."
#         },
#         "thickness": {
#           "type": "number",
#           "description": "Thickness of the deposited film in nm.",
#           "unit": "nm"
#         },
#         "epitaxy": {
#           "type": "string",
#           "description": "Type of epitaxy observed, e.g., van der Waals epitaxy."
#         },
#         "domainSize": {
#           "type": "number",
#           "description": "Average size of the domains in the film in nm.",
#           "unit": "nm"
#         }
#       }
#     }
#   },
#   "required": [
#     "processConditions",
#     "precursor",
#     "substrate",
#     "filmProperties"
#   ]
# }
