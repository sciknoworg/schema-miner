# %% [markdown]
# ## 🌐 Ontology Grounding with QUDT

# %% [markdown]
# Once a process schema is extracted, it can be semantically grounded using the [QUDT Ontologies](https://www.qudt.org/pages/HomePage.html) (Quantities, Units, Dimensions, and Data Types). This step ensures that schema attributes are linked to standardized scientific units and quantities, enabling interoperability and machine reasoning.

# %% [markdown]
# **Overview**
# 1. [Intalling Schema_miner](#installing-schema_miner)
# 2. [Configuration](#configuration)
# 3. [Ontology Grounding with QUDT Using LLM Prompting](#ontology-grounding-with-qudt-using-llm-prompting)
# 4. [Ontology Grounding with QUDT Using Agentic Workflow](#ontology-grounding-with-qudt-using-agentic-workflow)

# %% [markdown]
# ### 🗂️ Installing Schema_miner <a id='installing-schema-miner'></a>
#
# You can install schema-miner via **pip**:
#
# ```bash
# pip install -i https://test.pypi.org/simple/ schema-miner
# ```
#
# Or directly from GitHub (latest development version):
#
# ```bash
# pip install git+https://github.com/sciknoworg/schema-miner.git
# ```

# %% [markdown]
# ### 🛠️ Configuration <a id='configuration'></a>
#
# Before running schema-miner, configure your environment.

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Configure logging
import logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s"
)

# %%
from schema_miner.config.envConfig import EnvConfig
EnvConfig.OPENAI_api_key = '<insert-your-openai-key>'
EnvConfig.OPENAI_organization_id = '<insert-your-openi-organization-id>'

# %% [markdown]
# ### 🧪 Process Setup
#
# In this notebook, we demonstrate schema grounding on the domain of **Atomic Layer Deposition (ALD)**.
# This process involves alternating exposures of a substrate to chemical precursors, enabling precise thin-film growth at the atomic scale.
#
# > 💡 To adapt this notebook to a new domain, replace the domain name/description here and update the input literature paths in the Data Setup section.

# %%
# Add process name and process description whose schema have to be extracted
from schema_miner.config.processConfig import ProcessConfig
ProcessConfig.Process_name = "Atomic Layer Deposition"
ProcessConfig.Process_description = "An ALD process involves a series of controlled chemical reactions used to deposit thin films on a surface at an atomic level"

# %% [markdown]
# ### 🌐 Ontology Grounding with QUDT Using LLM Prompting <a id='prompt-grounding'></a>
#
# In this approach, we ask the LLM directly to suggest ontology matches for schema properties from its prior knowledge.

# %%
import json
from pathlib import Path
from schema_miner.ontology_grounding.prompt_qudt_grounding import prompt_based_qudt_grounding

# %%
# Large Language Model (LLM) to be used for Schema Extraction
llm_model_name = 'gpt-4o'

# Ground the schema with QUDT Ontology
process_schema = Path('../results/stage-3/Atomic-Layer-Deposition/experimental-schema/gpt-4o.json')
results_file_path = Path("../results/qudt-grounded/Atomic-Layer-Deposition/experimental-schema")
schema = prompt_based_qudt_grounding(llm_model_name, process_schema, results_file_path, save_schema = True)

# %%
# Display the final Process Schema
logging.info(f'{ProcessConfig.Process_name} Schema:\n{json.dumps(schema, indent = 2)}')
# Out:
# 2025-09-17 16:01:49,696 - root - INFO - Atomic Layer Deposition Schema:
# {
#   "$schema": "http://json-schema.org/draft-07/schema#",
#   "title": "Atomic Layer Deposition Process",
#   "type": "object",
#   "properties": {
#     "reactantSelection": {
#       "type": "object",
#       "description": "Details about the precursor and co-reactant selection.",
#       "properties": {
#         "precursor": {
#           "type": "string",
#           "description": "The chemical compound used as the precursor."
#         },
#         "coReactant": {
#           "type": "string",
#           "description": "The chemical compound used as the co-reactant."
#         },
#         "deliveryMethod": {
#           "type": "string",
#           "enum": [
#             "vapor drawn",
#             "carrier gas assisted",
#             "bubbling"
#           ],
#           "description": "Method of delivering the precursor to the chamber."
#         }
#       },
#       "required": [
#         "precursor",
#         "coReactant"
#       ]
#     },
#     "chemicalComposition": {
#       "type": "object",
#       "description": "Information about the chemical composition of the deposited film.",
#       "properties": {
#         "methods": {
#           "type": "array",
#           "items": {
#             "type": "string",
#             "enum": [
#               "XPS",
#               "RBS",
#               "four-point probe",
#               "refractive index"
#             ]
#           },
#           "description": "Methods used to verify chemical composition."
#         },
#         "purity": {
#           "type": "boolean",
#           "description": "Indicates if the material is of high purity."
#         }
#       }
#     },
#     "thicknessControl": {
#       "type": "object",
#       "description": "Details about the control of film thickness.",
#       "properties": {
#         "growthPerCycle": {
#           "type": "object",
#           "description": "Growth per cycle (GPC) in nm/cycle.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "minimum": 0
#                 },
#                 "unit": {
#                   "type": "object",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/LengthPerCycle"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "enum": [
#                         "https://qudt.org/vocab/unit/NM"
#                       ]
#                     }
#                   }
#                 }
#               }
#             },
#             "quantityKind": {
#               "type": "string",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/LengthPerCycle"
#               ]
#             }
#           }
#         },
#         "measurementMethods": {
#           "type": "array",
#           "items": {
#             "type": "string",
#             "enum": [
#               "spectroscopic ellipsometry",
#               "RBS",
#               "quartz-crystal microbalance"
#             ]
#           },
#           "description": "Methods used to measure film thickness."
#         }
#       }
#     },
#     "saturation": {
#       "type": "object",
#       "description": "Saturation behavior of the ALD process.",
#       "properties": {
#         "precursorDosingTime": {
#           "type": "object",
#           "description": "Time for precursor dosing in seconds.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "minimum": 0
#                 },
#                 "unit": {
#                   "type": "object",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Time"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "enum": [
#                         "https://qudt.org/vocab/unit/SEC"
#                       ]
#                     }
#                   }
#                 }
#               }
#             },
#             "quantityKind": {
#               "type": "string",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/Time"
#               ]
#             }
#           }
#         },
#         "precursorPurgeTime": {
#           "type": "object",
#           "description": "Time for precursor purge in seconds.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "minimum": 0
#                 },
#                 "unit": {
#                   "type": "object",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Time"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "enum": [
#                         "https://qudt.org/vocab/unit/SEC"
#                       ]
#                     }
#                   }
#                 }
#               }
#             },
#             "quantityKind": {
#               "type": "string",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/Time"
#               ]
#             }
#           }
#         },
#         "coReactantExposureTime": {
#           "type": "object",
#           "description": "Time for co-reactant exposure in seconds.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "minimum": 0
#                 },
#                 "unit": {
#                   "type": "object",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Time"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "enum": [
#                         "https://qudt.org/vocab/unit/SEC"
#                       ]
#                     }
#                   }
#                 }
#               }
#             },
#             "quantityKind": {
#               "type": "string",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/Time"
#               ]
#             }
#           }
#         },
#         "coReactantPurgeTime": {
#           "type": "object",
#           "description": "Time for co-reactant purge in seconds.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "minimum": 0
#                 },
#                 "unit": {
#                   "type": "object",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Time"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "enum": [
#                         "https://qudt.org/vocab/unit/SEC"
#                       ]
#                     }
#                   }
#                 }
#               }
#             },
#             "quantityKind": {
#               "type": "string",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/Time"
#               ]
#             }
#           }
#         }
#       }
#     },
#     "materialProperties": {
#       "type": "object",
#       "description": "Properties of the deposited material.",
#       "properties": {
#         "opticalProperties": {
#           "type": "object",
#           "properties": {
#             "refractiveIndex": {
#               "type": "number",
#               "description": "Refractive index of the material."
#             },
#             "absorptionCoefficient": {
#               "type": "number",
#               "description": "Absorption coefficient of the material."
#             }
#           }
#         },
#         "electricalProperties": {
#           "type": "object",
#           "properties": {
#             "resistivity": {
#               "type": "object",
#               "description": "Resistivity of the material in ohm-meter.",
#               "properties": {
#                 "quantityValue": {
#                   "type": "object",
#                   "properties": {
#                     "numericValue": {
#                       "type": "number"
#                     },
#                     "unit": {
#                       "type": "object",
#                       "properties": {
#                         "hasQuantityKind": {
#                           "type": "string",
#                           "enum": [
#                             "https://qudt.org/vocab/quantitykind/ElectricResistivity"
#                           ]
#                         },
#                         "sameAs": {
#                           "type": "string",
#                           "enum": [
#                             "https://qudt.org/vocab/unit/OHM_M"
#                           ]
#                         }
#                       }
#                     }
#                   }
#                 },
#                 "quantityKind": {
#                   "type": "string",
#                   "enum": [
#                     "https://qudt.org/vocab/quantitykind/ElectricResistivity"
#                   ]
#                 }
#               }
#             },
#             "carrierDensity": {
#               "type": "number",
#               "description": "Carrier density in the material."
#             },
#             "mobility": {
#               "type": "number",
#               "description": "Carrier mobility in the material."
#             }
#           }
#         },
#         "morphology": {
#           "type": "object",
#           "properties": {
#             "roughness": {
#               "type": "number",
#               "description": "Surface roughness of the film."
#             },
#             "crystallinity": {
#               "type": "string",
#               "description": "Crystallinity of the film."
#             }
#           }
#         },
#         "density": {
#           "type": "object",
#           "description": "Density of the deposited film in g/cm^3.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "properties": {
#                 "numericValue": {
#                   "type": "number"
#                 },
#                 "unit": {
#                   "type": "object",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Density"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "enum": [
#                         "https://qudt.org/vocab/unit/G-PER-CM3"
#                       ]
#                     }
#                   }
#                 }
#               }
#             },
#             "quantityKind": {
#               "type": "string",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/Density"
#               ]
#             }
#           }
#         }
#       }
#     },
#     "temperatureDependence": {
#       "type": "object",
#       "description": "Temperature dependence of the ALD process.",
#       "properties": {
#         "temperatureRange": {
#           "type": "array",
#           "items": {
#             "type": "object",
#             "description": "Temperature range for deposition in Celsius.",
#             "properties": {
#               "quantityValue": {
#                 "type": "object",
#                 "properties": {
#                   "numericValue": {
#                     "type": "number"
#                   },
#                   "unit": {
#                     "type": "object",
#                     "properties": {
#                       "hasQuantityKind": {
#                         "type": "string",
#                         "enum": [
#                           "https://qudt.org/vocab/quantitykind/Temperature"
#                         ]
#                       },
#                       "sameAs": {
#                         "type": "string",
#                         "enum": [
#                           "https://qudt.org/vocab/unit/DEG_C"
#                         ]
#                       }
#                     }
#                   }
#                 }
#               },
#               "quantityKind": {
#                 "type": "string",
#                 "enum": [
#                   "https://qudt.org/vocab/quantitykind/Temperature"
#                 ]
#               }
#             }
#           },
#           "minItems": 2,
#           "maxItems": 2
#         },
#         "ALDWindow": {
#           "type": "boolean",
#           "description": "Indicates if there is an ALD window with constant GPC."
#         }
#       }
#     },
#     "uniformity": {
#       "type": "object",
#       "description": "Uniformity of the film over large area substrates.",
#       "properties": {
#         "thicknessVariation": {
#           "type": "number",
#           "description": "Variation in film thickness across the substrate."
#         },
#         "propertyVariation": {
#           "type": "object",
#           "properties": {
#             "composition": {
#               "type": "boolean",
#               "description": "Indicates if composition varies across the substrate."
#             },
#             "resistivity": {
#               "type": "boolean",
#               "description": "Indicates if resistivity varies across the substrate."
#             }
#           }
#         }
#       }
#     },
#     "conformality": {
#       "type": "object",
#       "description": "Conformality of the film on 3D structures.",
#       "properties": {
#         "aspectRatio": {
#           "type": "number",
#           "description": "Aspect ratio of the structure used for conformality testing."
#         },
#         "thicknessRatio": {
#           "type": "number",
#           "description": "Ratio of thickness at different positions in the structure."
#         }
#       }
#     },
#     "nucleationBehavior": {
#       "type": "object",
#       "description": "Nucleation behavior during initial ALD cycles.",
#       "properties": {
#         "initialGrowthMode": {
#           "type": "string",
#           "enum": [
#             "linear",
#             "accelerated",
#             "delayed"
#           ],
#           "description": "Initial growth mode during nucleation."
#         },
#         "defectDensity": {
#           "type": "number",
#           "description": "Density of defects or pinholes in the film."
#         }
#       }
#     },
#     "otherAspects": {
#       "type": "object",
#       "description": "Other important aspects of ALD process development.",
#       "properties": {
#         "safety": {
#           "type": "string",
#           "description": "Safety considerations for chemicals and reaction products."
#         },
#         "filmStability": {
#           "type": "string",
#           "description": "Stability of the deposited films over time and environmental sensitivity."
#         },
#         "reproducibility": {
#           "type": "boolean",
#           "description": "Indicates if the same film properties can be consistently reproduced."
#         },
#         "precursorConsumption": {
#           "type": "number",
#           "description": "Efficiency of precursor use, related to the total surface area of the substrate."
#         },
#         "precursorStability": {
#           "type": "string",
#           "description": "Stability of the precursor under prolonged heating."
#         },
#         "literatureComparison": {
#           "type": "boolean",
#           "description": "Indicates if results align with existing literature."
#         },
#         "devicePerformance": {
#           "type": "string",
#           "description": "Performance of the film in a working device application."
#         }
#       }
#     },
#     "reactivity": {
#       "type": "object",
#       "description": "Reactivity related to process conditions.",
#       "properties": {
#         "temperatureEffect": {
#           "type": "string",
#           "description": "Effect of temperature on reactivity and film properties."
#         },
#         "hydrogenConcentration": {
#           "type": "number",
#           "description": "Hydrogen concentration in the film, which may vary with temperature."
#         }
#       }
#     },
#     "epitaxy": {
#       "type": "object",
#       "description": "Details about epitaxial growth conditions and characteristics.",
#       "properties": {
#         "vdWEpitaxy": {
#           "type": "boolean",
#           "description": "Indicates if van der Waals epitaxy is used."
#         },
#         "substrateInteraction": {
#           "type": "string",
#           "description": "Description of substrate interaction and alignment."
#         },
#         "domainSize": {
#           "type": "object",
#           "description": "Average domain size of the epitaxial film in nm.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "properties": {
#                 "numericValue": {
#                   "type": "number"
#                 },
#                 "unit": {
#                   "type": "object",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Length"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "enum": [
#                         "https://qudt.org/vocab/unit/NM"
#                       ]
#                     }
#                   }
#                 }
#               }
#             },
#             "quantityKind": {
#               "type": "string",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/Length"
#               ]
#             }
#           }
#         },
#         "inPlaneAlignment": {
#           "type": "string",
#           "description": "Description of in-plane alignment of the film."
#         }
#       }
#     }
#   },
#   "required": [
#     "reactantSelection",
#     "chemicalComposition",
#     "thicknessControl",
#     "saturation",
#     "materialProperties",
#     "temperatureDependence",
#     "uniformity",
#     "conformality",
#     "nucleationBehavior",
#     "otherAspects",
#     "epitaxy"
#   ]
# }

# %% [markdown]
# ### 🌐 Ontology Grounding with QUDT Using Agentic Workflow <a id='agentic-grounding'></a>
#
# Here we use an agent-based pipeline to ground schema elements. The agent retrieves ontology candidates, reasons over matches, and validates outputs.

# %%
from schema_miner.ontology_grounding.agentic_qudt_grounding import agentic_qudt_grounding

# %%
# Large Language Model (LLM) to be used for Schema Extraction
llm_model_name = 'gpt-4o'

# Ground the schema with QUDT Ontology
process_schema = Path('../results/stage-3/Atomic-Layer-Deposition/experimental-schema/gpt-4o.json')
results_file_path = Path("../results/agentic-qudt-grounded/Atomic-Layer-Deposition/experimental-schema")
schema = agentic_qudt_grounding(llm_model_name, process_schema, results_file_path, save_schema = True)

# %%
# Display the final Process Schema
logging.info(f'{ProcessConfig.Process_name} Schema:\n{json.dumps(schema, indent = 2)}')
# Out:
# 2025-09-17 16:17:55,645 - root - INFO - Atomic Layer Deposition Schema:
# {
#   "$schema": "http://json-schema.org/draft-07/schema#",
#   "title": "Atomic Layer Deposition Process",
#   "type": "object",
#   "properties": {
#     "reactantSelection": {
#       "type": "object",
#       "description": "Details about the precursor and co-reactant selection.",
#       "properties": {
#         "precursor": {
#           "type": "string",
#           "description": "The chemical compound used as the precursor."
#         },
#         "coReactant": {
#           "type": "object",
#           "description": "The chemical compound used as the co-reactant.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "http://qudt.org/3.1.0/vocab/quantitykind/ChemicalAffinity"
#                       ],
#                       "sameAs": [
#                         "http://qudt.org/vocab/unit/J-PER-MOL"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "http://qudt.org/3.1.0/vocab/quantitykind/ChemicalAffinity"
#               ]
#             }
#           }
#         },
#         "deliveryMethod": {
#           "type": "string",
#           "enum": [
#             "vapor drawn",
#             "carrier gas assisted",
#             "bubbling"
#           ],
#           "description": "Method of delivering the precursor to the chamber."
#         }
#       },
#       "required": [
#         "precursor",
#         "coReactant"
#       ]
#     },
#     "chemicalComposition": {
#       "type": "object",
#       "description": "Information about the chemical composition of the deposited film.",
#       "properties": {
#         "methods": {
#           "type": "object",
#           "items": {
#             "type": "string",
#             "enum": [
#               "XPS",
#               "RBS",
#               "four-point probe",
#               "refractive index"
#             ]
#           },
#           "description": "Methods used to verify chemical composition.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Concentration"
#                       ],
#                       "sameAs": [
#                         "https://qudt.org/vocab/unit/MOL-PER-L",
#                         "https://qudt.org/vocab/unit/MOL-PER-M3"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/Concentration"
#               ]
#             }
#           }
#         },
#         "purity": {
#           "type": "object",
#           "description": "Indicates if the material is of high purity.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/MassFraction"
#                       ],
#                       "sameAs": []
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/MassFraction"
#               ]
#             }
#           }
#         }
#       }
#     },
#     "thicknessControl": {
#       "type": "object",
#       "description": "Details about the control of film thickness.",
#       "properties": {
#         "growthPerCycle": {
#           "type": "object",
#           "description": "Growth per cycle (GPC) in nm/cycle.",
#           "minimum": 0,
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Length"
#                       ],
#                       "sameAs": [
#                         "https://qudt.org/vocab/unit/NanoM"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/Length"
#               ]
#             }
#           }
#         },
#         "measurementMethods": {
#           "type": "object",
#           "items": {
#             "type": "string",
#             "enum": [
#               "spectroscopic ellipsometry",
#               "RBS",
#               "quartz-crystal microbalance"
#             ]
#           },
#           "description": "Methods used to measure film thickness.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Thickness"
#                       ],
#                       "sameAs": [
#                         "https://qudt.org/vocab/unit/ANGSTROM",
#                         "https://qudt.org/vocab/unit/MicroM",
#                         "https://qudt.org/vocab/unit/NanoM",
#                         "https://qudt.org/vocab/unit/MilliM"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/Thickness"
#               ]
#             }
#           }
#         }
#       }
#     },
#     "saturation": {
#       "type": "object",
#       "description": "Saturation behavior of the ALD process.",
#       "properties": {
#         "precursorDosingTime": {
#           "type": "object",
#           "description": "Time for precursor dosing in seconds.",
#           "minimum": 0,
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "http://qudt.org/vocab/quantitykind/Time"
#                       ],
#                       "sameAs": [
#                         "http://qudt.org/vocab/unit/SEC"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "http://qudt.org/vocab/quantitykind/Time"
#               ]
#             }
#           }
#         },
#         "precursorPurgeTime": {
#           "type": "object",
#           "description": "Time for precursor purge in seconds.",
#           "minimum": 0,
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "http://qudt.org/vocab/quantitykind/Time"
#                       ],
#                       "sameAs": [
#                         "http://qudt.org/vocab/unit/SEC"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "http://qudt.org/vocab/quantitykind/Time"
#               ]
#             }
#           }
#         },
#         "coReactantExposureTime": {
#           "type": "object",
#           "description": "Time for co-reactant exposure in seconds.",
#           "minimum": 0,
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "http://qudt.org/vocab/quantitykind/Time"
#                       ],
#                       "sameAs": [
#                         "http://qudt.org/vocab/unit/SEC"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "http://qudt.org/vocab/quantitykind/Time"
#               ]
#             }
#           }
#         },
#         "coReactantPurgeTime": {
#           "type": "object",
#           "description": "Time for co-reactant purge in seconds.",
#           "minimum": 0,
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Time"
#                       ],
#                       "sameAs": [
#                         "https://qudt.org/vocab/unit/SEC"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/Time"
#               ]
#             }
#           }
#         }
#       }
#     },
#     "materialProperties": {
#       "type": "object",
#       "description": "Properties of the deposited material.",
#       "properties": {
#         "opticalProperties": {
#           "type": "object",
#           "properties": {
#             "refractiveIndex": {
#               "type": "object",
#               "description": "Refractive index of the material.",
#               "properties": {
#                 "quantityValue": {
#                   "type": "object",
#                   "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#                   "properties": {
#                     "numericValue": {
#                       "type": "number",
#                       "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                     },
#                     "unit": {
#                       "type": "object",
#                       "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                       "properties": {
#                         "hasQuantityKind": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                           "enum": [
#                             "https://qudt.org/vocab/quantitykind/RefractiveIndex"
#                           ],
#                           "sameAs": [
#                             "https://qudt.org/vocab/unit/UNITLESS"
#                           ]
#                         },
#                         "sameAs": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                         }
#                       }
#                     }
#                   },
#                   "required": [
#                     "numericValue",
#                     "unit"
#                   ]
#                 },
#                 "quantityKind": {
#                   "type": "string",
#                   "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                   "enum": [
#                     "https://qudt.org/vocab/quantitykind/RefractiveIndex"
#                   ]
#                 }
#               }
#             },
#             "absorptionCoefficient": {
#               "type": "object",
#               "description": "Absorption coefficient of the material.",
#               "properties": {
#                 "quantityValue": {
#                   "type": "object",
#                   "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#                   "properties": {
#                     "numericValue": {
#                       "type": "number",
#                       "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                     },
#                     "unit": {
#                       "type": "object",
#                       "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                       "properties": {
#                         "hasQuantityKind": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                           "enum": [
#                             "https://qudt.org/vocab/quantitykind/AttenuationCoefficient"
#                           ],
#                           "sameAs": [
#                             "https://qudt.org/vocab/unit/M2-PER-MOL",
#                             "https://qudt.org/vocab/unit/PER-M"
#                           ]
#                         },
#                         "sameAs": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                         }
#                       }
#                     }
#                   },
#                   "required": [
#                     "numericValue",
#                     "unit"
#                   ]
#                 },
#                 "quantityKind": {
#                   "type": "string",
#                   "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                   "enum": [
#                     "https://qudt.org/vocab/quantitykind/AttenuationCoefficient"
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         "electricalProperties": {
#           "type": "object",
#           "properties": {
#             "resistivity": {
#               "type": "object",
#               "description": "Resistivity of the material in ohm-meter.",
#               "properties": {
#                 "quantityValue": {
#                   "type": "object",
#                   "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#                   "properties": {
#                     "numericValue": {
#                       "type": "number",
#                       "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                     },
#                     "unit": {
#                       "type": "object",
#                       "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                       "properties": {
#                         "hasQuantityKind": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                           "enum": [
#                             "https://qudt.org/vocab/quantitykind/Resistivity"
#                           ],
#                           "sameAs": [
#                             "https://qudt.org/vocab/unit/GigaOHM-M",
#                             "https://qudt.org/vocab/unit/KiloOHM-M",
#                             "https://qudt.org/vocab/unit/MegaOHM-KiloM",
#                             "https://qudt.org/vocab/unit/MegaOHM-M",
#                             "https://qudt.org/vocab/unit/MicroOHM-M",
#                             "https://qudt.org/vocab/unit/MilliOHM-M",
#                             "https://qudt.org/vocab/unit/NanoOHM-M",
#                             "https://qudt.org/vocab/unit/OHM-CentiM",
#                             "https://qudt.org/vocab/unit/OHM-KiloM",
#                             "https://qudt.org/vocab/unit/OHM-M"
#                           ]
#                         },
#                         "sameAs": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                         }
#                       }
#                     }
#                   },
#                   "required": [
#                     "numericValue",
#                     "unit"
#                   ]
#                 },
#                 "quantityKind": {
#                   "type": "string",
#                   "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                   "enum": [
#                     "https://qudt.org/vocab/quantitykind/Resistivity"
#                   ]
#                 }
#               }
#             },
#             "carrierDensity": {
#               "type": "object",
#               "description": "Carrier density in the material.",
#               "properties": {
#                 "quantityValue": {
#                   "type": "object",
#                   "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#                   "properties": {
#                     "numericValue": {
#                       "type": "number",
#                       "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                     },
#                     "unit": {
#                       "type": "object",
#                       "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                       "properties": {
#                         "hasQuantityKind": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                           "enum": [
#                             "https://qudt.org/vocab/quantitykind/IntinsicCarrierDensity"
#                           ],
#                           "sameAs": [
#                             "https://qudt.org/vocab/unit/NUM-PER-M3",
#                             "https://qudt.org/vocab/unit/NUM-PER-L",
#                             "https://qudt.org/vocab/unit/NUM-PER-MicroL",
#                             "https://qudt.org/vocab/unit/NUM-PER-MilliL",
#                             "https://qudt.org/vocab/unit/NUM-PER-MilliM3",
#                             "https://qudt.org/vocab/unit/NUM-PER-NanoL",
#                             "https://qudt.org/vocab/unit/NUM-PER-PicoL"
#                           ]
#                         },
#                         "sameAs": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                         }
#                       }
#                     }
#                   },
#                   "required": [
#                     "numericValue",
#                     "unit"
#                   ]
#                 },
#                 "quantityKind": {
#                   "type": "string",
#                   "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                   "enum": [
#                     "https://qudt.org/vocab/quantitykind/IntinsicCarrierDensity"
#                   ]
#                 }
#               }
#             },
#             "mobility": {
#               "type": "object",
#               "description": "Carrier mobility in the material.",
#               "properties": {
#                 "quantityValue": {
#                   "type": "object",
#                   "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#                   "properties": {
#                     "numericValue": {
#                       "type": "number",
#                       "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                     },
#                     "unit": {
#                       "type": "object",
#                       "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                       "properties": {
#                         "hasQuantityKind": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                           "enum": [
#                             "https://qudt.org/vocab/quantitykind/Mobility"
#                           ],
#                           "sameAs": [
#                             "https://qudt.org/vocab/unit/CentiM2-PER-V-SEC",
#                             "https://qudt.org/vocab/unit/M2-PER-V-SEC"
#                           ]
#                         },
#                         "sameAs": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                         }
#                       }
#                     }
#                   },
#                   "required": [
#                     "numericValue",
#                     "unit"
#                   ]
#                 },
#                 "quantityKind": {
#                   "type": "string",
#                   "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                   "enum": [
#                     "https://qudt.org/vocab/quantitykind/Mobility"
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         "morphology": {
#           "type": "object",
#           "properties": {
#             "roughness": {
#               "type": "object",
#               "description": "Surface roughness of the film.",
#               "properties": {
#                 "quantityValue": {
#                   "type": "object",
#                   "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#                   "properties": {
#                     "numericValue": {
#                       "type": "number",
#                       "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                     },
#                     "unit": {
#                       "type": "object",
#                       "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                       "properties": {
#                         "hasQuantityKind": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                           "enum": [],
#                           "sameAs": [
#                             "http://qudt.org/vocab/unit/MICRO_M",
#                             "http://qudt.org/vocab/unit/NANO_M"
#                           ]
#                         },
#                         "sameAs": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                         }
#                       }
#                     }
#                   },
#                   "required": [
#                     "numericValue",
#                     "unit"
#                   ]
#                 },
#                 "quantityKind": {
#                   "type": "string",
#                   "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                   "enum": []
#                 }
#               }
#             },
#             "crystallinity": {
#               "type": "object",
#               "description": "Crystallinity of the film.",
#               "properties": {
#                 "quantityValue": {
#                   "type": "object",
#                   "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#                   "properties": {
#                     "numericValue": {
#                       "type": "number",
#                       "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                     },
#                     "unit": {
#                       "type": "object",
#                       "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                       "properties": {
#                         "hasQuantityKind": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                           "enum": [],
#                           "sameAs": []
#                         },
#                         "sameAs": {
#                           "type": "string",
#                           "format": "uri",
#                           "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                         }
#                       }
#                     }
#                   },
#                   "required": [
#                     "numericValue",
#                     "unit"
#                   ]
#                 },
#                 "quantityKind": {
#                   "type": "string",
#                   "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                   "enum": []
#                 }
#               }
#             }
#           }
#         },
#         "density": {
#           "type": "object",
#           "description": "Density of the deposited film in g/cm^3.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/MassDensity"
#                       ],
#                       "sameAs": [
#                         "https://qudt.org/vocab/unit/GM-PER-CentiM3"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/MassDensity"
#               ]
#             }
#           }
#         }
#       }
#     },
#     "temperatureDependence": {
#       "type": "object",
#       "description": "Temperature dependence of the ALD process.",
#       "properties": {
#         "temperatureRange": {
#           "type": "object",
#           "items": {
#             "type": "number"
#           },
#           "description": "Temperature range for deposition in Celsius.",
#           "minItems": 2,
#           "maxItems": 2,
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Temperature"
#                       ],
#                       "sameAs": [
#                         "https://qudt.org/vocab/unit/DEG_C",
#                         "https://qudt.org/vocab/unit/K"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/Temperature"
#               ]
#             }
#           }
#         },
#         "ALDWindow": {
#           "type": "object",
#           "description": "Indicates if there is an ALD window with constant GPC.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Temperature"
#                       ],
#                       "sameAs": [
#                         "https://qudt.org/vocab/unit/DEG_C",
#                         "https://qudt.org/vocab/unit/K",
#                         "https://qudt.org/vocab/unit/DEG_F"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/Temperature"
#               ]
#             }
#           }
#         }
#       }
#     },
#     "uniformity": {
#       "type": "object",
#       "description": "Uniformity of the film over large area substrates.",
#       "properties": {
#         "thicknessVariation": {
#           "type": "object",
#           "description": "Variation in film thickness across the substrate.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "http://qudt.org/3.1.0/vocab/quantitykind/Length"
#                       ],
#                       "sameAs": [
#                         "http://qudt.org/3.1.0/vocab/unit/ANGSTROM",
#                         "http://qudt.org/3.1.0/vocab/unit/M",
#                         "http://qudt.org/3.1.0/vocab/unit/NanoM",
#                         "http://qudt.org/3.1.0/vocab/unit/MicroM",
#                         "http://qudt.org/3.1.0/vocab/unit/MilliM",
#                         "http://qudt.org/3.1.0/vocab/unit/IN",
#                         "http://qudt.org/3.1.0/vocab/unit/FT"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "http://qudt.org/3.1.0/vocab/quantitykind/Length"
#               ]
#             }
#           }
#         },
#         "propertyVariation": {
#           "type": "object",
#           "properties": {
#             "composition": {
#               "type": "boolean",
#               "description": "Indicates if composition varies across the substrate."
#             },
#             "resistivity": {
#               "type": "object",
#               "description": "Indicates if resistivity varies across the substrate.",
#               "properties": {
#                 "quantityValue": {
#                   "type": "object",
# ...
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Temperature"
#                       ],
#                       "sameAs": [
#                         "https://qudt.org/vocab/unit/DEG_C"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/Temperature"
#               ]
#             }
#           }
#         },
#         "literatureComparison": {
#           "type": "boolean",
#           "description": "Indicates if results align with existing literature."
#         },
#         "devicePerformance": {
#           "type": "object",
#           "description": "Performance of the film in a working device application.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/ThermalEfficiency"
#                       ],
#                       "sameAs": [
#                         "https://qudt.org/vocab/unit/FRACTION",
#                         "https://qudt.org/vocab/unit/PERCENT",
#                         "https://qudt.org/vocab/unit/UNITLESS"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/ThermalEfficiency"
#               ]
#             }
#           }
#         }
#       }
#     },
#     "reactivity": {
#       "type": "object",
#       "description": "Reactivity related to process conditions.",
#       "properties": {
#         "temperatureEffect": {
#           "type": "object",
#           "description": "Effect of temperature on reactivity and film properties.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Reactivity",
#                         "https://qudt.org/vocab/quantitykind/Temperature"
#                       ],
#                       "sameAs": [
#                         "https://qudt.org/vocab/unit/DEG_C",
#                         "https://qudt.org/vocab/unit/K"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/Reactivity",
#                 "https://qudt.org/vocab/quantitykind/Temperature"
#               ]
#             }
#           }
#         },
#         "hydrogenConcentration": {
#           "type": "object",
#           "description": "Hydrogen concentration in the film, which may vary with temperature.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "http://qudt.org/vocab/quantitykind/Concentration",
#                         "http://qudt.org/vocab/quantitykind/Reactivity",
#                         "http://qudt.org/vocab/quantitykind/Temperature"
#                       ],
#                       "sameAs": [
#                         "http://qudt.org/vocab/unit/MOL-PER-L",
#                         "http://qudt.org/vocab/unit/MOL-PER-M3",
#                         "http://qudt.org/vocab/unit/DEG_C"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "http://qudt.org/vocab/quantitykind/Concentration",
#                 "http://qudt.org/vocab/quantitykind/Reactivity",
#                 "http://qudt.org/vocab/quantitykind/Temperature"
#               ]
#             }
#           }
#         }
#       }
#     },
#     "epitaxy": {
#       "type": "object",
#       "description": "Details about epitaxial growth conditions and characteristics.",
#       "properties": {
#         "vdWEpitaxy": {
#           "type": "boolean",
#           "description": "Indicates if van der Waals epitaxy is used."
#         },
#         "substrateInteraction": {
#           "type": "object",
#           "description": "Description of substrate interaction and alignment.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/CrossSection",
#                         "https://qudt.org/vocab/quantitykind/ChemicalAffinity"
#                       ],
#                       "sameAs": [
#                         "https://qudt.org/vocab/unit/M2",
#                         "https://qudt.org/vocab/unit/BARN",
#                         "https://qudt.org/vocab/unit/J-PER-MOL"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/CrossSection",
#                 "https://qudt.org/vocab/quantitykind/ChemicalAffinity"
#               ]
#             }
#           }
#         },
#         "domainSize": {
#           "type": "object",
#           "description": "Average domain size of the epitaxial film in nm.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Length"
#                       ],
#                       "sameAs": [
#                         "https://qudt.org/vocab/unit/NanoM"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/Length"
#               ]
#             }
#           }
#         },
#         "inPlaneAlignment": {
#           "type": "object",
#           "description": "Description of in-plane alignment of the film.",
#           "properties": {
#             "quantityValue": {
#               "type": "object",
#               "description": "The measured or observed value of the physical quantity, expressed as a numeric value along with its associated unit.",
#               "properties": {
#                 "numericValue": {
#                   "type": "number",
#                   "description": "The numerical magnitude of the physical quantity (e.g., 9.81, 25.0)."
#                 },
#                 "unit": {
#                   "type": "object",
#                   "description": "The unit of measurement associated with the numeric value, following QUDT ontology terms.",
#                   "properties": {
#                     "hasQuantityKind": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#                       "enum": [
#                         "https://qudt.org/vocab/quantitykind/Angle"
#                       ],
#                       "sameAs": [
#                         "https://qudt.org/vocab/unit/DEG",
#                         "https://qudt.org/vocab/unit/RAD"
#                       ]
#                     },
#                     "sameAs": {
#                       "type": "string",
#                       "format": "uri",
#                       "description": "An external identifier or URI that provides a reference equivalent to this unit"
#                     }
#                   }
#                 }
#               },
#               "required": [
#                 "numericValue",
#                 "unit"
#               ]
#             },
#             "quantityKind": {
#               "type": "string",
#               "description": "The QUDT URI of the quantity kind that categorizes the physical property measured by this unit.",
#               "enum": [
#                 "https://qudt.org/vocab/quantitykind/Angle"
#               ]
#             }
#           }
#         }
#       }
#     }
#   },
#   "required": [
#     "reactantSelection",
#     "chemicalComposition",
#     "thicknessControl",
#     "saturation",
#     "materialProperties",
#     "temperatureDependence",
#     "uniformity",
#     "conformality",
#     "nucleationBehavior",
#     "otherAspects",
#     "epitaxy"
#   ]
# }
